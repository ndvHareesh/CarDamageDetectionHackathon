# %%
import pandas as pd
df=pd.read_excel('training_label.xlsx')
df.head(50)
# Out:
#             image                                           class  \
# 0    image/0.jpeg                                  dent,head_lamp
# 1    image/1.jpeg                                       head_lamp
# 2    image/2.jpeg                                         scratch
# 3    image/3.jpeg                                       head_lamp
# 4    image/4.jpeg                                         unknown
# 5    image/5.jpeg                                  dent,head_lamp
# 6    image/6.jpeg                                   glass_shatter
# 7    image/7.jpeg                                  dent,head_lamp
# 8    image/8.jpeg                                       tail_lamp
# 9    image/9.jpeg                                            dent
# 10  image/10.jpeg                                         scratch
# 11  image/11.jpeg                                            dent
# 12  image/12.jpeg                                            dent
# ...

# %%
df['class'][0]

words = [word.lower() for word in df['class'][16].split(',')]
words.sort()

# %%
class_sorted=[]

for i in range(801):
    words = [word.lower() for word in df['class'][i].split(',')]
    words.sort()
    s = ","
    s = s.join(words)
    class_sorted.append((s))

# %%
class_sorted
# Out:
# ['dent,head_lamp',
#  'head_lamp',
#  'scratch',
#  'head_lamp',
#  'unknown',
#  'dent,head_lamp',
#  'glass_shatter',
#  'dent,head_lamp',
#  'tail_lamp',
#  'dent',
#  'scratch',
#  'dent',
#  'dent',
#  'dent,scratch',
#  'glass_shatter',
#  'dent,glass_shatter,head_lamp,scratch,tail_lamp',
#  'dent,head_lamp',
#  'dent',
#  'glass_shatter',
#  'dent,glass_shatter,scratch',
#  'dent',
#  'dent,head_lamp',
#  'dent',
#  'unknown',
#  'dent',
#  'unknown',
#  'glass_shatter',
#  'scratch',
#  'unknown',
#  'scratch',
#  'tail_lamp',
#  'dent,glass_shatter,head_lamp,scratch,tail_lamp',
#  'scratch',
#  'dent,head_lamp,scratch',
#  'tail_lamp',
#  'unknown',
#  'head_lamp',
#  'unknown',
#  'unknown',
#  'dent',
#  'dent,glass_shatter,head_lamp,scratch',
#  'dent',
#  'scratch',
#  'unknown',
#  'scratch',
#  'dent',
#  'dent',
#  'glass_shatter',
#  'unknown',
#  'dent',
#  'dent',
#  'scratch',
#  'scratch,tail_lamp',
#  'dent,glass_shatter,head_lamp,scratch,tail_lamp',
# ...

# %%
df['class_sorted'] = class_sorted

# %%
df.head(50)
# Out:
#             image                                           class  \
# 0    image/0.jpeg                                  dent,head_lamp
# 1    image/1.jpeg                                       head_lamp
# 2    image/2.jpeg                                         scratch
# 3    image/3.jpeg                                       head_lamp
# 4    image/4.jpeg                                         unknown
# 5    image/5.jpeg                                  dent,head_lamp
# 6    image/6.jpeg                                   glass_shatter
# 7    image/7.jpeg                                  dent,head_lamp
# 8    image/8.jpeg                                       tail_lamp
# 9    image/9.jpeg                                            dent
# 10  image/10.jpeg                                         scratch
# 11  image/11.jpeg                                            dent
# 12  image/12.jpeg                                            dent
# ...

# %%
print(df['class_sorted'].unique())
# Out:
# ['dent,head_lamp' 'head_lamp' 'scratch' 'unknown' 'glass_shatter'
#  'tail_lamp' 'dent' 'dent,scratch'
#  'dent,glass_shatter,head_lamp,scratch,tail_lamp'
#  'dent,glass_shatter,scratch' 'dent,head_lamp,scratch'
#  'dent,glass_shatter,head_lamp,scratch' 'scratch,tail_lamp'
#  'dent,scratch,tail_lamp' 'head_lamp,scratch' 'dent,tail_lamp'
#  'dent,glass_shatter']

# %%
# df2=df[['image','class']]
# df2.head()
df3=df[['image','class_sorted']].replace(['image/'], '',regex=True)
#df4=df3.replace([','],'_',regex=True)
df3.head()
# Remover column header and index
df3.to_csv("train_lex.csv",index=False)

# %%
df3.head(5)
# Out:
#     image    class_sorted
# 0  0.jpeg  dent,head_lamp
# 1  1.jpeg       head_lamp
# 2  2.jpeg         scratch
# 3  3.jpeg       head_lamp
# 4  4.jpeg         unknown

# %%
df3.rename(columns = {'class':'classes'}, inplace = True)

# %%
df3.head()
# Out:
#     image    class_sorted
# 0  0.jpeg  dent,head_lamp
# 1  1.jpeg       head_lamp
# 2  2.jpeg         scratch
# 3  3.jpeg       head_lamp
# 4  4.jpeg         unknown

# %%
from __future__ import print_function
import pandas as pd
import shutil
import os
import sys

labels = pd.read_csv(r'train_lex.csv')

train_dir =r'Train'
DR = r"DR_6c_lex"
if not os.path.exists(DR):
    os.mkdir(DR)

for filename, class_name in labels.values:
    # Create subdirectory with `class_name`
    if not os.path.exists(DR +'/'+ str(class_name)):
        os.mkdir(DR + '/'+str(class_name))
    src_path = train_dir + '/'+ filename ##+ '.jpeg'
    dst_path = DR+'/' + str(class_name) + '/' + filename ##+ '.jpeg'
    try:
        shutil.copy(src_path, dst_path)
        print("sucessful")
    except IOError as e:
        print('Unable to copy file {} to {}'
              .format(src_path, dst_path))
    except:
        print('When try copy file {} to {}, unexpected error: {}'
              .format(src_path, dst_path, sys.exc_info()))
# Out:
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# sucessful
# ...

# %% [markdown]
# THE END
